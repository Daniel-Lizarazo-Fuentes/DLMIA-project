# %%
# %pip install numpy
# %pip install pyvista
# %pip install "pyvista[jupyter]" 
# %pip install trame ipywidgets
# %pip install matplotlib
# %pip install torch torchvision torchaudio
# %pip install nnunetv2
# %pip install simpleitk
# %pip install os
# %pip install json
# %pip install nibabel
# %pip install monai


#!python -c "import monai" || pip install -U "monai-weekly[fire, nibabel, yaml, tqdm, einops]"
#%env CUDA_VISIBLE_DEVICES=0

# %%
import numpy as np
import SimpleITK as sitk
import pyvista as pv
import matplotlib.pyplot as plt
import os
import json

import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

from monai.apps.auto3dseg import AutoRunner
from monai.config import print_config
from monai.data import create_test_image_3d

print_config()

# %% [markdown]
# # Loading in the data

# %%
#volume = pv.read(f"nnUNet_raw/Dataset100_normal/imagesTr/NORMAL_001_0000.nrrd")
#centerline = pv.read(f"nnUNet_raw/Dataset100_normal/labelsTr/NORMAL_001.nrrd")
#annotations = pv.read(f"nnUNet_raw/Dataset100_normal/ReorientedCenterlines/Normal_1.vtp")
#mesh = pv.read(f"nnUNet_raw/Dataset100_normal/ReorientedMeshes/Normal_1.stl")



# %%


sim_datalist = {
#    "testing": [
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/0.nrrd", "label": ""},
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/1.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/2.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/3.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/4.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/5.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/6.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/7.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/8.nrrd", "label": },
#        {"image": "nnUNet_raw/Dataset100_normal/testing_data/9.nrrd", "label": },
#    ],
    "training": [
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_1.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_1.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_2.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_2.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_3.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_3.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_4.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_4.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_5.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_5.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_6.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_6.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_7.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_7.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_8.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_8.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_9.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_9.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_10.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_10.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_11.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_11.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_12.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_12.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_13.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_13.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_14.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_14.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_15.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_15.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_16.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_16.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_17.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_17.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_18.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_18.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_19.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_19.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Normal_20.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Normal_20.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_1.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_1.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_2.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_2.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_3.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_3.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_4.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_4.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_5.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_5.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_6.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_6.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_7.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_7.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_8.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_8.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_9.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_9.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_10.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_10.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_11.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_11.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_12.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_12.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_13.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_13.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_14.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_14.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_15.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_15.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_16.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_16.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_17.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_17.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_18.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_18.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_19.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_19.nrrd"},
        {"fold": 0, "image": "nnUNet_raw/Dataset100_normal/imagesTr/Diseased_20.nrrd", "label": "nnUNet_raw/Dataset100_normal/labelsTr/Diseased_20.nrrd"}
    ],
}

sim_dim = (64, 64, 64)

import SimpleITK as sitk

def convert_nrrd_to_nifti(nrrd_path, nifti_path):
    img = sitk.ReadImage(nrrd_path)
    sitk.WriteImage(img, nifti_path)

# Define paths
raw_data_dir = "nnUNet_raw/Dataset100_normal"
output_data_dir = "./2ndauto3dseg_dir/sim_dataroot"

# Ensure output directory exists
os.makedirs(os.path.join(output_data_dir, "imagesTr"), exist_ok=True)
os.makedirs(os.path.join(output_data_dir, "labelsTr"), exist_ok=True)

# Convert all NRRD images and labels
image_filenames = sorted(os.listdir(os.path.join(raw_data_dir, "imagesTr")))
label_filenames = sorted(os.listdir(os.path.join(raw_data_dir, "labelsTr")))

for img_file, lbl_file in zip(image_filenames, label_filenames):
    img_nrrd_path = os.path.join(raw_data_dir, "imagesTr", img_file)
    lbl_nrrd_path = os.path.join(raw_data_dir, "labelsTr", lbl_file)

    # Change file extension from .nrrd to .nii.gz
    img_nii_path = os.path.join(output_data_dir, "imagesTr", img_file.replace(".nrrd", ".nii.gz"))
    lbl_nii_path = os.path.join(output_data_dir, "labelsTr", lbl_file.replace(".nrrd", ".nii.gz"))

    # Convert NRRD to NIfTI
    convert_nrrd_to_nifti(img_nrrd_path, img_nii_path)
    convert_nrrd_to_nifti(lbl_nrrd_path, lbl_nii_path)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
